# %%
import os
import sys

module_path = os.path.abspath(os.path.join("..", "src"))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils.portfolio import Portfolio
from utils.tickers import tickers
from strategies.strategy05 import Strategy05

# %%
portfolio = Portfolio(tickers=tickers, start="2023-01-01", end="2024-12-31")
nvda = portfolio.get_asset("NVDA")
nvda.get_data()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00   14.838841   14.983723   14.084459   14.303280
# 2023-01-04 00:00:00-05:00   14.555074   14.840839   14.229341   14.736924
# 2023-01-05 00:00:00-05:00   14.479137   14.552078   14.136418   14.253323
# 2023-01-06 00:00:00-05:00   14.462149   14.997711   14.022510   14.846834
# 2023-01-09 00:00:00-05:00   15.271488   16.042855   15.128604   15.615206
# ...                               ...         ...         ...         ...
# 2024-12-23 00:00:00-05:00  136.267463  139.777134  135.107566  139.657150
# 2024-12-24 00:00:00-05:00  139.987127  141.886946  138.637245  140.207108
# 2024-12-26 00:00:00-05:00  139.687155  140.837058  137.717335  139.917130
# 2024-12-27 00:00:00-05:00  138.537258  139.007216  134.697615  136.997391
# 2024-12-30 00:00:00-05:00  134.817597  140.257099  134.007674  137.477356
#
# ...

# %%
strat = Strategy05()
df = nvda.apply_strategy(strat)
df[df["TotalSignal"] != 0]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-02-01 00:00:00-05:00   19.674876   21.174647   19.594942   20.925852
# 2023-02-02 00:00:00-05:00   20.982806   21.931028   20.683052   21.691225
# 2023-02-08 00:00:00-05:00   22.368671   22.859270   21.989982   22.186821
# 2023-02-10 00:00:00-05:00   21.672242   22.059923   20.793962   21.247589
# 2023-02-13 00:00:00-05:00   21.520365   22.029948   20.944837   21.770161
# ...                               ...         ...         ...         ...
# 2024-12-23 00:00:00-05:00  136.267463  139.777134  135.107566  139.657150
# 2024-12-24 00:00:00-05:00  139.987127  141.886946  138.637245  140.207108
# 2024-12-26 00:00:00-05:00  139.687155  140.837058  137.717335  139.917130
# 2024-12-27 00:00:00-05:00  138.537258  139.007216  134.697615  136.997391
# 2024-12-30 00:00:00-05:00  134.817597  140.257099  134.007674  137.477356
#
# ...
